# %% [markdown]
# # Preprocess tweets - from clean_tweets pickle
# #### Text is already cleaned in step 1. In this step- tokenize, remove stop words, vectorize...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set()
#nlp preprocessing libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import pickle
from nltk.probability import FreqDist

# %%
## Load cleaned data from pickle
#read files from the folder
path = '/content/drive/MyDrive/Guvi Files/Final Project2(Tweets)/'
train_tweets = pd.read_pickle(path+'data/train_tweets_clean.pkl')
test_tweets = pd.read_pickle(path+'data/test_tweets_clean.pkl')

# %%
train_tweets.head()
# Out:
#    label                                              tweet  \
# 0      0   @user when a father is dysfunctional and is s...
# 1      0  @user @user thanks for #lyft credit i can't us...
# 2      0                                bihday your majesty
# 3      0  #model   i love u take with u all the time in ...
# 4      0             factsguide: society now    #motivation
#
#                                          clean_tweet
# 0    when a father is dysfunctional and is so sel...
# 1    thanks for  credit i cant use cause they don...
# 2                                bihday your majesty
# 3         i love u take with u all the time in ur
# 4                            factsguide society now

# %%
test_tweets.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet
# 0                                          to find
# 1      want everyone to see the new     and heres...
# 2                        safe ways to heal your
# 3  is the hp and the cursed child book up for res...
# 4    to my amazing hilarious  eli ahmir uncle dav...

# %%
#extract train tweets & labels separately
train_clean_tweets = train_tweets['clean_tweet']
train_target = train_tweets['label']

# %% [markdown]
# ## Tokenize and remove stop words

# %%
#remove stop words in train_clean_tweets
nltk.download('punkt')
nltk.download('stopwords')
stop_words = stopwords.words('english')
def tokenize_and_remove_stopwords(text):
    tokens = nltk.word_tokenize(text)
    filtered_tokens = [token for token in tokens if token.lower() not in stop_words]
    return filtered_tokens
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
processed_data = list(map(tokenize_and_remove_stopwords,train_clean_tweets))
print(processed_data)
# Out:
# [['father', 'dysfunctional', 'selfish', 'drags', 'kids', 'dysfunction'], ['thanks', 'credit', 'cant', 'use', 'cause', 'dont', 'offer', 'wheelchair', 'vans', 'pdx'], ['bihday', 'majesty'], ['love', 'u', 'take', 'u', 'time', 'ur'], ['factsguide', 'society'], ['huge', 'fan', 'fare', 'big', 'talking', 'leave', 'chaos', 'pay', 'disputes', 'get'], ['camping', 'tomorrow', 'danny'], ['next', 'school', 'year', 'year', 'exams', 'cant', 'think'], ['love', 'land'], ['welcome', 'im'], ['consumer', 'price', 'index', 'climbed', 'previous', 'may'], ['selfish'], ['get', 'see', 'daddy', 'today'], ['calls', 'middle', 'school', 'build', 'wall', 'chant'], ['comment'], ['ouchjunior', 'angry'], ['thankful', 'paner'], ['retweet', 'agree'], ['smiles', 'around', 'via', 'ig', 'user', 'make', 'people'], ['know', 'essential', 'oils', 'made', 'chemicals'], ['people', 'blaming', 'ha', 'conceded', 'goal', 'fat', 'rooney', 'gave', 'away', 'free', 'kick', 'knowing', 'bale', 'hit'], ['sad', 'little', 'dude'], ['product', 'day', 'happy', 'man', 'tool', 'whos', 'time', 'open', 'drink'], ['lumpy', 'says', 'prove', 'lumpy'], [], ['beautiful', 'sign', 'vendor'], ['sunday', 'love'], ['great', 'panel', 'mediatization', 'public', 'service'], ['happy', 'fathers', 'day'], ['people', 'went', 'nightclub', 'good', 'night', 'mans', 'actions', 'means', 'people', 'lost', 'families', 'forever'], ['never', 'chance', 'vote', 'presidential', 'candidate', 'excited', 'cycle', 'looks', 'different'], [], ['rip', 'fellow', 'nohern', 'ireland', 'fan', 'sadley', 'passed', 'away', 'tonight', 'gawa', 'forever', 'singing', 'cheering', 'fire'], ['hard', 'monday', 'due', 'cloudy', 'weather', 'disabling', 'oxygen', 'production', 'today'], ['unbelievable', 'century', 'wed', 'need', 'something', 'like'], ['bull', 'dominate', 'bull', 'direct', 'whatever', 'want', 'w'], ['morning'], ['one', 'word', 'tells'], ['oh', 'waited', 'hours', 'valravn', 'line', 'stopped', 'working', 'close'], ['thankful', 'sunshine'], ['finally', 'finish', 'book', 'youve', 'working', 'awhile'], ['yup', 'knicks', 'fan', 'hard', 'easier', 'nba', 'fan', 'playoffs', 'roll', 'around'], ['life', 'social', 'networking', 'embrace', 'day'], ['mom', 'shares', 'bihday', 'bihday', 'snake', 'see', 'weekend'], ['lovely', 'echeveria', 'blooms'], ['amazing'], ['love', 'u', 'take', 'u', 'time', 'ur'], ['im', 'goes'], ['feeling', 'blue'], ['best', 'pa', 'life', 'knowing'], ['getting', 'ready', 'remove', 'victums', 'frm'], ['got', 'love'], ['concelebrate', 'first', 'time'], ['let', 'scumbaggery', 'begin'], ['thank', 'super', 'love', 'zpamdelacruz', 'dolores', 'capas', 'tarlac'], ['scourge', 'playing', 'baroque', 'pieces', 'piano', 'beyond', 'belief'], ['lets', 'fight'], ['happy', 'fathers', 'day', 'mr', 'rayos'], ['ascot', 'times', 'babe'], ['weekendis'], ['happy', 'work', 'conference', 'right', 'mindset', 'leads', 'cultureofdevelopment', 'organizations'], ['christina', 'grimmies', 'last', 'performance', 'shot', 'via'], ['ready', 'dance'], ['youve', 'really', 'hu', 'feelings'], ['wife', 'adore', 'miss', 'poland', 'show', 'surgery', 'name', 'bridget', 'shes', 'everything'], ['jealous', 'right'], ['celebrate', 'every', 'man', 'played', 'fatherly', 'role', 'fathers', 'day'], ['im', 'sure', 'happy', 'hour'], ['white', 'establishment', 'cant', 'blk', 'folx', 'running', 'around', 'loving', 'promoting', 'greatness'], ['good', 'morning', 'journey', 'begins'], ['like'], ['new', 'brochures', 'arrived', 'exciting'], ['much', 'stuff', 'happening', 'florida', 'first', 'shooting', 'two', 'year', 'old', 'kid'], ['ferrari', 'sake', 'championship', 'gp', 'clearly', 'turning', 'point', 'rb', 'ferrarimercs'], ['aced', 'first', 'test'], ['seeks', 'probe', 'leak', 'points', 'finger'], ['wrapping'], ['hey', 'white', 'people', 'call', 'people', 'white'], ['might', 'shown', 'today', 'regurgitated', 'talking', 'points', 'name', 'calling'], ['sometimes', 'raise', 'brows', 'raise', 'bar'], [], ['designing', 'learning', 'space', 'include', 'h'], ['uses', 'insecurity',  ...

# %%
total_vocab = set()
for comment in processed_data:
    total_vocab.update(comment)
len(total_vocab)
# Out:
# 22203

# %%
# store the processed data
with open(path+'data/processed_data.pkl', 'wb') as f:
    pickle.dump(processed_data, f)

# %% [markdown]
# ## Top words in corpus

# %%
# morphing `processed_data` into a readable list
flat_filtered = [item for sublist in processed_data for item in sublist]
# getting frequency distribution
clean_corpus_freqdist = FreqDist(flat_filtered)
# top 20 words in cleaned corpus
clean_corpus_freqdist.most_common(20)
# Out:
# [('day', 2026),
#  ('happy', 1575),
#  ('love', 1205),
#  ('im', 1148),
#  ('u', 1137),
#  ('time', 1085),
#  ('like', 973),
#  ('today', 939),
#  ('new', 917),
#  ('get', 915),
#  ('cant', 808),
#  ('people', 803),
#  ('good', 790),
#  ('one', 774),
#  ('see', 753),
#  ('dont', 729),
#  ('life', 712),
#  ('go', 649),
#  ('want', 647),
#  ('take', 615)]

# %% [markdown]
# ## Lemmatization

# %%
#lemmatize processed_data and convert from list of words to sentence again
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lemmatized_output = []

for lst in processed_data:
    lemmed = ' '.join([lemmatizer.lemmatize(w) for w in lst])
    lemmatized_output.append(lemmed)

#convert list to df before pickling
# lemmatized_output = pd.DataFrame(lemmatized_output)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
print(lemmatized_output)
# Out:
# ['father dysfunctional selfish drag kid dysfunction', 'thanks credit cant use cause dont offer wheelchair van pdx', 'bihday majesty', 'love u take u time ur', 'factsguide society', 'huge fan fare big talking leave chaos pay dispute get', 'camping tomorrow danny', 'next school year year exam cant think', 'love land', 'welcome im', 'consumer price index climbed previous may', 'selfish', 'get see daddy today', 'call middle school build wall chant', 'comment', 'ouchjunior angry', 'thankful paner', 'retweet agree', 'smile around via ig user make people', 'know essential oil made chemical', 'people blaming ha conceded goal fat rooney gave away free kick knowing bale hit', 'sad little dude', 'product day happy man tool who time open drink', 'lumpy say prove lumpy', '', 'beautiful sign vendor', 'sunday love', 'great panel mediatization public service', 'happy father day', 'people went nightclub good night man action mean people lost family forever', 'never chance vote presidential candidate excited cycle look different', '', 'rip fellow nohern ireland fan sadley passed away tonight gawa forever singing cheering fire', 'hard monday due cloudy weather disabling oxygen production today', 'unbelievable century wed need something like', 'bull dominate bull direct whatever want w', 'morning', 'one word tell', 'oh waited hour valravn line stopped working close', 'thankful sunshine', 'finally finish book youve working awhile', 'yup knicks fan hard easier nba fan playoff roll around', 'life social networking embrace day', 'mom share bihday bihday snake see weekend', 'lovely echeveria bloom', 'amazing', 'love u take u time ur', 'im go', 'feeling blue', 'best pa life knowing', 'getting ready remove victums frm', 'got love', 'concelebrate first time', 'let scumbaggery begin', 'thank super love zpamdelacruz dolores capas tarlac', 'scourge playing baroque piece piano beyond belief', 'let fight', 'happy father day mr rayos', 'ascot time babe', 'weekendis', 'happy work conference right mindset lead cultureofdevelopment organization', 'christina grimmies last performance shot via', 'ready dance', 'youve really hu feeling', 'wife adore miss poland show surgery name bridget shes everything', 'jealous right', 'celebrate every man played fatherly role father day', 'im sure happy hour', 'white establishment cant blk folx running around loving promoting greatness', 'good morning journey begin', 'like', 'new brochure arrived exciting', 'much stuff happening florida first shooting two year old kid', 'ferrari sake championship gp clearly turning point rb ferrarimercs', 'aced first test', 'seek probe leak point finger', 'wrapping', 'hey white people call people white', 'might shown today regurgitated talking point name calling', 'sometimes raise brow raise bar', '', 'designing learning space include h', 'us insecurity lure men', 'carrying gun wouldnt helped cant take gun control wont stop black market terrorism get worse', 'use power mind body', 'woohoo week go', 'far away place family member hus', 'ready rehearse tonight new music new video look announcement', 'monday night channel finally get see fuss', 'watching new episode', 'offline nice long night', 'thing incredibly', 'yes received acceptance letter master back october', 'daughter riding bike around driveway son playing guitar u enjoy campfire', 'omg loving station way jam work getting work done course', 'ill always hope one day ill get hug dont think gon na happen anytime soon', 'love u take u time ur', 'couple sex fat naked japanese girl', 'day edwardsville pennsylvania', 'personalised gbp get', 'truly sick ppl', 'trump calling obama resign orlando shooting boy point year talk change', 'long', 'clear barrier jump fresh week high', 'going la tomorrow', 'thankful good friend', 'still wrap head around fact gone fact man destroyed', 'received dis cant wait sta baking', 'playing via', 'yes yes yes', 'sunday', 'im interested doesnt address racism brings', 'one beloved long lost cd recovered thanks apple musi ...

# %%
#pickle these for modeling
with open(path+'data/lemmatized_data.pkl', 'wb') as f:
    pickle.dump(lemmatized_output, f)

train_target.to_pickle(path+'data/train_target.pkl')
