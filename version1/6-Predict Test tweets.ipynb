# %% [markdown]
# # Prediction
# 1. Logistict Regerssion and SVM models are stored as pickles
# 2. Cleaned test tweets are also stored as pickle file
# 3. Load test tweets, Vectorize/Tokenize/Pad as needed by the respective models
# 4. Load Models
# 5. Predict the outcome and store the result in an excel

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
# nlp preprocessing libs
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Load cleaned test tweets

# %%
## Load cleaned data from pickle
#read files from the folder
path = '/content/drive/MyDrive/Guvi Files/Final Project2(Tweets)/'
test_tweets = pd.read_pickle(path+'data/test_tweets_clean.pkl')

# %%
test_tweets.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet
# 0                                          to find
# 1      want everyone to see the new     and heres...
# 2                        safe ways to heal your
# 3  is the hp and the cursed child book up for res...
# 4    to my amazing hilarious  eli ahmir uncle dav...

# %%
# keep only clean_tweet
full_tweets = test_tweets.copy(deep=True)
test_tweets = test_tweets['clean_tweet']

# %%
full_tweets.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet
# 0                                          to find
# 1      want everyone to see the new     and heres...
# 2                        safe ways to heal your
# 3  is the hp and the cursed child book up for res...
# 4    to my amazing hilarious  eli ahmir uncle dav...

# %% [markdown]
# ## Remove stopwords and tokenize test tweets

# %%
nltk.download('stopwords')
nltk.download('punkt')
stop_words = stopwords.words('english')
def tokenize_and_remove_stopwords(text):
    tokens = nltk.word_tokenize(text)
    filtered_tokens = [token for token in tokens if token.lower() not in stop_words]
    return filtered_tokens
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# tokenize and remove stop words
processed_data = list(map(tokenize_and_remove_stopwords,test_tweets))
print(processed_data)
# Out:
# [['find'], ['want', 'everyone', 'see', 'new', 'heres'], ['safe', 'ways', 'heal'], ['hp', 'cursed', 'child', 'book', 'reservations', 'already', 'yes'], ['amazing', 'hilarious', 'eli', 'ahmir', 'uncle', 'dave', 'loves', 'misses'], ['choose'], ['something', 'inside', 'dies', 'eyes', 'ness'], [], ['never', 'understand', 'dad', 'left', 'young'], ['mannaepicure'], ['narcosis', 'infinite', 'ep', 'make', 'aware', 'grinding', 'neuro', 'bass'], ['one', 'worlds', 'greatest', 'spoing', 'events'], ['half', 'way', 'website'], ['good', 'food', 'good', 'life', 'called', 'garlic', 'bread'], ['ill', 'stand', 'behind'], ['atei', 'ate', 'ate'], ['got', 'limited', 'edition', 'rain', 'shine', 'set', 'today'], ['keep'], ['london', 'united', 'kingdom'], ['thought', 'factory', 'bbc', 'neutrality', 'right', 'wing', 'fascism', 'gt'], ['hey', 'guys', 'tommorow', 'last', 'day', 'exams', 'im', 'happy', 'yay'], ['memories'], ['mind', 'like', 'body', 'like'], ['never', 'entire', 'life'], ['check', 'twitterww', 'trends', 'trending', 'worldwide', 'bst'], ['thought', 'saw', 'mermaid'], ['chick', 'gets', 'fucked', 'hottest', 'naked', 'lady'], ['happy', 'bday', 'lucy', 'xoxo'], ['haroldfriday', 'weekend', 'filled', 'sunbeams', 'everyone'], ['tried', 'nothing', 'try', 'know', 'loved', 'light', 'fave', 'deep', 'rivers'], ['ill', 'im'], ['new', 'episode', 'tk', 'really', 'cool', 'year', 'anniversary', 'ep', 'works', 'august'], ['attack', 'bull', 'game', 'really', 'think', 'head', 'empty', 'around', 'city', 'side'], ['suppo', 'fisherman', 'bullying', 'racism'], ['say', 'im', 'speaking', 'collectively', 'ive', 'always', 'known', 'showed', 'lot'], ['wish', 'could', 'talk'], ['food', 'time', 'haylie', 'hot', 'chocolate', 'mummy', 'thank', 'god', 'friday'], ['snow', 'white', 'gt', 'open', 'gt', 'dm', 'us', 'today'], ['ladies', 'cloth'], ['wasnt'], ['tomorrow', 'fun', 'seeing', 'old', 'friend', 'shooting', 'something', 'super', 'fun'], ['food', 'diet', 'benefits'], ['trumps', 'invested', 'billions', 'saudi', 'empowers', 'people', 'funding', 'isis'], ['granddaughters', 'bihday', 'tomorrow', 'going', 'pick', 'play', 'house', 'little', 'car', 'pool', 'today'], ['happiest', 'place', 'eah'], ['baby', 'dave', 'due', 'born', 'october', 'fav', 'band', 'time', 'playing', 'weekend', 'lol'], ['loving', 'every', 'day'], ['morning', 'sunshine'], ['makes', 'makes', 'john'], ['foods', 'body'], ['enjoying', 'sunshine', 'god', 'good'], ['fathers', 'idol'], ['reason', 'maintainers', 'android', 'provide', 'clear', 'basic', 'code', 'examples', 'docs'], ['nice', 'luxuryweek'], ['cause', 'get', 'live', 'together', 'whole', 'week'], ['back', 'thursday', 'bih', 'day', 'bro', 'chege'], ['thankful', 'fun'], ['saw', 'shes', 'craying', 'coz', 'baby', 'hard', 'breath', 'strong', 'yeah', 'baby', 'god'], ['happened'], ['lets', 'thing'], ['time'], ['love', 'u', 'take', 'u', 'time', 'ur'], ['help'], ['good', 'sunday', 'everyone'], ['cousins', 'asking', 'always', 'shawldi', 'ko', 'lang', 'masabi', 'coz', 'po', 'im', 'getting', 'fat', 'braso', 'getting', 'bigger'], ['r', 'others', 'b'], ['time', 'pint', 'seeing', 'coldplay', 'wembleyyyy'], ['current', 'mood'], ['chioma', 'noble', 'igwes', 'special', 'day'], ['cant', 'believe', 'left', 'school', 'years', 'ago', 'weeks', 'time', 'ill', 'teaching', 'classes'], ['lipolight', 'helped', 'shape', 'help', 'shape', 'learn'], ['ahhh', 'leaving', 'tomorrow'], ['blessed', 'hear', 'morning', 'chorus', 'good', 'morning', 'people', 'friday'], ['aunti', 'mi', 'find', 'hilarious', 'posts', 'nigeria', 'enough', 'trouble'], ['chapters', 'left', 'book', 'nearly', 'complete', 'hard', 'read'], ['thrilled', 'working', 'coming', 'months', 'announcements', 'soon'], ['trying', 'another', 'way', 'make', 'one', 'may', 'underproofed'], ['cool', 'old', 'door', 'window', 'vendor'], ['team'], ['greatbritain', 'eyes', 'skies', 'rafredarrows', 'fly', 'past', 'mall', 'say'], ['followerswe', 'blessed', 'love', 'everyone', 'suppos', 'us', 'thx', 'much', 'fishing', 'f'], ['lt', 'feeding', 'pub ...

# %% [markdown]
# ## Lemmatize

# %%
#lemmatize processed_data and convert from list of words to sentence again
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lemmatized_output = []

for lst in processed_data:
    lemmed = ' '.join([lemmatizer.lemmatize(w) for w in lst])
    lemmatized_output.append(lemmed)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
print(lemmatized_output)
# Out:
# ['find', 'want everyone see new here', 'safe way heal', 'hp cursed child book reservation already yes', 'amazing hilarious eli ahmir uncle dave love miss', 'choose', 'something inside dy eye ness', '', 'never understand dad left young', 'mannaepicure', 'narcosis infinite ep make aware grinding neuro bass', 'one world greatest spoing event', 'half way website', 'good food good life called garlic bread', 'ill stand behind', 'atei ate ate', 'got limited edition rain shine set today', 'keep', 'london united kingdom', 'thought factory bbc neutrality right wing fascism gt', 'hey guy tommorow last day exam im happy yay', 'memory', 'mind like body like', 'never entire life', 'check twitterww trend trending worldwide bst', 'thought saw mermaid', 'chick get fucked hottest naked lady', 'happy bday lucy xoxo', 'haroldfriday weekend filled sunbeam everyone', 'tried nothing try know loved light fave deep river', 'ill im', 'new episode tk really cool year anniversary ep work august', 'attack bull game really think head empty around city side', 'suppo fisherman bullying racism', 'say im speaking collectively ive always known showed lot', 'wish could talk', 'food time haylie hot chocolate mummy thank god friday', 'snow white gt open gt dm u today', 'lady cloth', 'wasnt', 'tomorrow fun seeing old friend shooting something super fun', 'food diet benefit', 'trump invested billion saudi empowers people funding isi', 'granddaughter bihday tomorrow going pick play house little car pool today', 'happiest place eah', 'baby dave due born october fav band time playing weekend lol', 'loving every day', 'morning sunshine', 'make make john', 'food body', 'enjoying sunshine god good', 'father idol', 'reason maintainer android provide clear basic code example doc', 'nice luxuryweek', 'cause get live together whole week', 'back thursday bih day bro chege', 'thankful fun', 'saw shes craying coz baby hard breath strong yeah baby god', 'happened', 'let thing', 'time', 'love u take u time ur', 'help', 'good sunday everyone', 'cousin asking always shawldi ko lang masabi coz po im getting fat braso getting bigger', 'r others b', 'time pint seeing coldplay wembleyyyy', 'current mood', 'chioma noble igwes special day', 'cant believe left school year ago week time ill teaching class', 'lipolight helped shape help shape learn', 'ahhh leaving tomorrow', 'blessed hear morning chorus good morning people friday', 'aunti mi find hilarious post nigeria enough trouble', 'chapter left book nearly complete hard read', 'thrilled working coming month announcement soon', 'trying another way make one may underproofed', 'cool old door window vendor', 'team', 'greatbritain eye sky rafredarrows fly past mall say', 'followerswe blessed love everyone suppos u thx much fishing f', 'lt feeding public trough piggy', 'website live makeup fresh look', 'forecast look good weather across', 'happy shooting love monica', 'happy father day fathersday', 'stardivarius friday new history new outfit post', 'final countdown official u publication june', 'happy trusted first know', 'interview feat grandmaster flash ze lovely message via', 'im getting hour work training im', 'life right amazing', 'social medium reality really get viual acceptance seems really thing ocialmedia', 'seven tomorrow finalagainst next week plus scrim', 'ignorant ill informed tweet r silly childish one dimensional', 'great see look forward welcoming digme', 'jackblair na', 'u take pour one big cup drink delivered', 'happy father day dad hope u great day love u fathersday', 'working anatomy studyguide since pm still done', 'worry', 'getting ready kubamba father day kambua noel gg moh blessed', 'ya know guy feeling stressed donut thing feel happy know follower sticking', 'pa', 'electronic music', 'back people', 'l v e', 'happy saturday tune', 'many alum friend waking shocked hear death scsu president', 'im disappointed yesterday argument wasnt even baselessly accused living mother basement', 'hey ivanka bracelet feel good profiti ...

# %% [markdown]
# ## Vectorize

# %%
# Load the fitted TfidfVectorizer from training
with open(path + 'data/train_tfidf.pkl', 'rb') as file:
    tfidf_trained = pickle.load(file)

# %%
#vectorize using TFIDFVectorizer
X_test_tfidf = tfidf_trained.transform(lemmatized_output)

# %% [markdown]
# ## Load Logistic Regression Model from Pickle

# %%
# load model from pickle file
with open('/content/drive/MyDrive/Guvi Files/Final Project2(Tweets)/models/final_model_lr.pkl', 'rb') as file:
    lr_model = pickle.load(file)

# %% [markdown]
# ### Predict using LR Model

# %%
lr_prediction = lr_model.predict(X_test_tfidf)

# %%
print(lr_prediction)
# Out:
# [0 0 0 ... 0 0 0]

# %%
# convert lr_repdiction to dataframe
lr_prediction = pd.DataFrame(lr_prediction)

# %%
lr_prediction[0].value_counts()
# Out:
# 0
# 0    15854
# 1     1343
# Name: count, dtype: int64

# %%
# add the prediction to test tweets
full_tweets['lr_prediction'] = lr_prediction[0]

# %%
full_tweets.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet  lr_prediction
# 0                                          to find                0
# 1      want everyone to see the new     and heres...              0
# 2                        safe ways to heal your                   0
# 3  is the hp and the cursed child book up for res...              0
# 4    to my amazing hilarious  eli ahmir uncle dav...              0

# %% [markdown]
# ## Prediction using SVM Model

# %%
# load SVM model stored
with open('/content/drive/MyDrive/Guvi Files/Final Project2(Tweets)/models/svm_base_model.pkl', 'rb') as file:
    svm_model = pickle.load(file)

# %%
svm_prediction = svm_model.predict(X_test_tfidf)

# %%
svm_prediction = pd.DataFrame(svm_prediction)
full_tweets['svm_prediction'] = svm_prediction[0]

# %%
full_tweets.head()
# Out:
#                                                tweet  \
# 0  #studiolife #aislife #requires #passion #dedic...
# 1   @user #white #supremacists want everyone to s...
# 2  safe ways to heal your #acne!!    #altwaystohe...
# 3  is the hp and the cursed child book up for res...
# 4    3rd #bihday to my amazing, hilarious #nephew...
#
#                                          clean_tweet  lr_prediction  \
# 0                                          to find                0
# 1      want everyone to see the new     and heres...              0
# 2                        safe ways to heal your                   0
# 3  is the hp and the cursed child book up for res...              0
# 4    to my amazing hilarious  eli ahmir uncle dav...              0
#
#    svm_prediction
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
# Write test_tweet to an excel file
full_tweets.to_excel('/content/drive/MyDrive/Guvi Files/Final Project2(Tweets)/models/test_tweets_prediction.xlsx', index=False)
